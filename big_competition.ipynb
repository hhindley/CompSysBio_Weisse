# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import solve_ivp

# %%
# setup code from growth_model_inc_abx notebook

# degradation
def deg(x, dm):
    return x * dm

# ribosome binding
def r_b(mx, r, kb):
    return kb * mx * r  

# ribosome unbinding
def r_ub(cx, ku):
    return cx * ku

# transcription rate
def tx(w, theta, a, q=None, Kq=None, nq=None): 
    if q is not None and Kq is not None and nq is not None:
        return (w * a / (theta + a)) / (1 + (q / (Kq )) ** nq)
    else:
        return w * a / (theta + a)

# translation rate
def tlr(a, nx, cx, gmax, Kgamma):
    gamma = gmax * a / (Kgamma + a) 
    return (gamma / nx) * cx

# energy consumption
def ttrate(a, cr, ct, cm, cq, gmax, Kgamma):
    gamma = gmax * a / (Kgamma + a)
    return (cr + ct + cm + cq) * gamma

# import 
def vimp(et, vt, s0, Kt):
    return et * vt * s0 / (Kt + s0)

# metabolism
def vcat(em, si, vm, Km):
    return em * vm * si / (Km + si)

# growth rate
def lam(a, cr, ct, cm, cq, gmax, Kgamma, M):
    gamma = gmax * a / (Kgamma + a)
    ttrate = (cr + ct + cm + cq) * gamma
    lam = ttrate / M
    return lam

# antibiotic binding
def abx_bind(cx, Cm, k_cm):
    return cx * Cm * k_cm

# %%
# model from growth_model_ode notebook or add your own from previously completed notebook

def abx_model(t, y, params):

    # parameters 
    dm, kb, ku, thetar, s0, gmax, thetax, Kt, M, we, Km, vm, nx, Kq, vt, wr, wq, nq, nr, ns, Kgamma, Cm, k_cm = params

    # species (LHS)
    mt, mm, mq, mr, ct, cm, cq, cr, et, em, q, r, si, a, zmt, zmm, zmq, zmr = y
    
    # RHS of ODE
    dydt = np.zeros(18) # the order of the RHS will match the order of species in y eg. dydt[0] = dmt/dt, dydt[1] = dmm/dt, dydt[2] = dmq/dt etc.

    # this model is just an extension of the previous one, so we will repeat the same steps with the addition of antibiotic binding 
    # transcription
    dmtdt = tx(we, thetax, a)
    dmmdt = tx(we, thetax, a)
    dmqdt = tx(wq, thetax, a, q=q, Kq=Kq, nq=nq)
    dmrdt = tx(wr, thetar, a)

    # mRNA degradation 
    dmtdt -= deg(mt, dm)
    dmmdt -= deg(mm, dm)
    dmqdt -= deg(mq, dm)
    dmrdt -= deg(mr, dm)

    # ribosome binding
    dmtdt -= r_b(mt, r, kb)
    dmmdt -= r_b(mm, r, kb)
    dmqdt -= r_b(mq, r, kb)
    dmrdt -= r_b(mr, r, kb)

    dctdt = r_b(mt, r, kb)
    dcmdt = r_b(mm, r, kb)
    dcqdt = r_b(mq, r, kb)
    dcrdt = r_b(mr, r, kb)

    drdt =  - r_b(mt, r, kb) - r_b(mm, r, kb) - r_b(mq, r, kb) - r_b(mr, r, kb)

    # ribosome unbinding 
    dmtdt += r_ub(ct, ku)
    dmmdt += r_ub(cm, ku)
    dmqdt += r_ub(cq, ku)
    dmrdt += r_ub(cr, ku)

    dctdt -= r_ub(ct, ku)
    dcmdt -= r_ub(cm, ku)
    dcqdt -= r_ub(cq, ku)
    dcrdt -= r_ub(cr, ku)

    drdt += r_ub(ct, ku) + r_ub(cm, ku) + r_ub(cq, ku) + r_ub(cr, ku)

    # translation
    dmtdt += tlr(a, nx, ct, gmax, Kgamma)
    dmmdt += tlr(a, nx, cm, gmax, Kgamma)
    dmqdt += tlr(a, nx, cq, gmax, Kgamma)
    dmrdt += tlr(a, nr, cr, gmax, Kgamma)

    dctdt -= tlr(a, nx, ct, gmax, Kgamma)
    dcmdt -= tlr(a, nx, cm, gmax, Kgamma)
    dcqdt -= tlr(a, nx, cq, gmax, Kgamma)
    dcrdt -= tlr(a, nr, cr, gmax, Kgamma)

    detdt = tlr(a, nx, ct, gmax, Kgamma)
    demdt = tlr(a, nx, cm, gmax, Kgamma)
    dqdt = tlr(a, nx, cq, gmax, Kgamma)
    drdt += tlr(a, nr, cr, gmax, Kgamma) + tlr(a, nr, cr, gmax, Kgamma) + tlr(a, nx, ct, gmax, Kgamma) + tlr(a, nx, cm, gmax, Kgamma) + tlr(a, nx, cq, gmax, Kgamma)

    # nutrient import
    dsidt = vimp(et, vt, s0, Kt)

    # metabolism
    dsidt -= vcat(em, si, vm, Km)
    dadt = (ns*vcat(em, si, vm, Km))

    # energy consumption
    dadt -= ttrate(a, cr, ct, cm, cq, gmax, Kgamma)

    # dilution by growth 
    dmtdt -= (lam(a, cr, ct, cm, cq, gmax, Kgamma, M) * mt)
    dmmdt -= (lam(a, cr, ct, cm, cq, gmax, Kgamma, M) * mm)
    dmqdt -= (lam(a, cr, ct, cm, cq, gmax, Kgamma, M) * mq)
    dmrdt -= (lam(a, cr, ct, cm, cq, gmax, Kgamma, M) * mr)

    dctdt -= (lam(a, cr, ct, cm, cq, gmax, Kgamma, M) * ct)   
    dcmdt -= (lam(a, cr, ct, cm, cq, gmax, Kgamma, M) * cm)   
    dcqdt -= (lam(a, cr, ct, cm, cq, gmax, Kgamma, M) * cq)
    dcrdt -= (lam(a, cr, ct, cm, cq, gmax, Kgamma, M) * cr)

    detdt -= (lam(a, cr, ct, cm, cq, gmax, Kgamma, M) * et)
    demdt -= (lam(a, cr, ct, cm, cq, gmax, Kgamma, M) * em)
    dqdt -= (lam(a, cr, ct, cm, cq, gmax, Kgamma, M) * q)
    drdt -= (lam(a, cr, ct, cm, cq, gmax, Kgamma, M) * r)

    dsidt -= (lam(a, cr, ct, cm, cq, gmax, Kgamma, M) * si)
    dadt -= (lam(a, cr, ct, cm, cq, gmax, Kgamma, M) * a)

    # antibiotic binding
    dctdt -= abx_bind(ct, Cm, k_cm)
    dcmdt -= abx_bind(cm, Cm, k_cm)
    dcqdt -= abx_bind(cq, Cm, k_cm)
    dcrdt -= abx_bind(cr, Cm, k_cm)

    dzmtdt = abx_bind(ct, Cm, k_cm)
    dzmmdt = abx_bind(cm, Cm, k_cm)
    dzmqdt = abx_bind(cq, Cm, k_cm)
    dzmrdt = abx_bind(cr, Cm, k_cm)

    # dilution for new zombie species
    dzmtdt -= (lam(a, cr, ct, cm, cq, gmax, Kgamma, M) * zmt)
    dzmmdt -= (lam(a, cr, ct, cm, cq, gmax, Kgamma, M) * zmm)
    dzmqdt -= (lam(a, cr, ct, cm, cq, gmax, Kgamma, M) * zmq)
    dzmrdt -= (lam(a, cr, ct, cm, cq, gmax, Kgamma, M) * zmr)

    # build full dydt system
    dydt[0] = dmtdt
    dydt[1] = dmmdt
    dydt[2] = dmqdt
    dydt[3] = dmrdt
    dydt[4] = dctdt
    dydt[5] = dcmdt
    dydt[6] = dcqdt
    dydt[7] = dcrdt
    dydt[8] = detdt
    dydt[9] = demdt
    dydt[10] = dqdt
    dydt[11] = drdt
    dydt[12] = dsidt
    dydt[13] = dadt

    # new species
    dydt[14] = dzmtdt
    dydt[15] = dzmmdt
    dydt[16] = dzmqdt
    dydt[17] = dzmrdt


    return dydt

# %%
def popmodel_ode(t, y, params):

    # parameters 
    dm, kb, ku, thetar, s0, gmax, thetax, Kt, M, we, Km, vm, nx, Kq, vt, wr, wq, nq, nr, ns, Kgamma, Cm, k_cm, kin, kdeath = params

    # ensure no negative concentrations
    y = np.maximum(y, 0)
    
    # species (LHS)
    mt, mm, mq, mr, ct, cm, cq, cr, et, em, q, r, si, a, zmt, zmm, zmq, zmr, s, N = y

    cell = y[:-2]
    cell_params = list(params[:-2])
    cell_params[4] = s  # update external nutrient concentration in params with species 
    dcelldt = abx_model(t, cell, cell_params) # insert your model in here

    # extracellular ODEs
    # nutrient influx and consumption
    v_imp   = et * vt * s / (Kt + s)
    dsdt    = kin - N * v_imp

    # population growth 
    gamma   = gmax * a / (Kgamma + a)
    lam  = gamma/M * (cr + ct + cm + cq)
    dNdt    = N * (lam - kdeath)

    return np.concatenate([dcelldt, [dsdt], [dNdt]])

# %%
def competition_ode_big(t, y, params):

    # ensure no negative concentrations
    y = np.maximum(y, 0)

    pop_size = len(y) // 6
    pop1 = y[:pop_size] # population 1 is the first sixth of y
    pop2 = y[pop_size:2*pop_size] # population 2 is the second sixth of y
    pop3 = y[2*pop_size:3*pop_size] # population 3 is the third sixth of y
    pop4 = y[3*pop_size:4*pop_size] # population 4 is the fourth sixth of y
    pop5 = y[4*pop_size:5*pop_size] # population 5 is the fifth sixth of y
    pop6 = y[5*pop_size:] # population 6 is the sixth sixth of y

    par_size = len(params) // 6
    par1 = params[:par_size] # parameters for pop1 is the first sixth of params
    par2 = params[par_size:2*par_size] # parameters for pop2 is the second sixth of params
    par3 = params[2*par_size:3*par_size] # parameters for pop3 is the third sixth of params
    par4 = params[3*par_size:4*par_size] # parameters for pop4 is the fourth sixth of params
    par5 = params[4*par_size:5*par_size] # parameters for pop5 is the fifth sixth of params
    par6 = params[5*par_size:] # parameters for pop6 is the sixth sixth of params

    dpop1dt = popmodel_ode(t, pop1, par1) # run the population model for pop1
    dpop2dt = popmodel_ode(t, pop2, par2) # run the population model for pop2
    dpop3dt = popmodel_ode(t, pop3, par3) # run the population model for pop3
    dpop4dt = popmodel_ode(t, pop4, par4) # run the population model for pop4
    dpop5dt = popmodel_ode(t, pop5, par5) # run the population model for pop5
    dpop6dt = popmodel_ode(t, pop6, par6) # run the population model for pop6

    kin = par1[-2] # kin is the same for both populations, so we can just take it from par1
    dsdt = - kin + dpop1dt[-2] + dpop2dt[-2] + dpop3dt[-2] + dpop4dt[-2] + dpop5dt[-2] + dpop6dt[-2] # update dsdt to be the sum of both populations minus kin as it's already included in both

    dpop1dt[-2] = dsdt 
    dpop2dt[-2] = dsdt
    dpop3dt[-2] = dsdt
    dpop4dt[-2] = dsdt
    dpop5dt[-2] = dsdt
    dpop6dt[-2] = dsdt

    return np.concatenate([dpop1dt, dpop2dt, dpop3dt, dpop4dt, dpop5dt, dpop6dt])

# %%
params_dict = {
    'dm': 0.1,
    'kb': 1,
    'ku': 1.0,
    'thetar': 426.8693338968694,
    's0': 1e4,
    'gmax': 1260.0,
    'thetax': 4.379733394834643,
    'Kt': 1.0e3,
    'M': 1.0e8,
    'we': 4.139172187824451,
    'Km': 1.0e3,
    'vm': 5800.0,
    'nx': 300.0,
    'Kq': 1.522190403737490e+05,
    'vt': 726.0,
    'wr': 929.9678874564831,
    'wq': 948.9349882947897,
    'nq': 4,
    'nr': 7549.0,
    'ns': 0.5,
    'Kgamma': 3e9,
    'Cm': 0,
    'k_cm': 0.005990373118888,
    'kin': 0,
    'kdeath': 0
}

def params_for_sim(param_dict):
    order = ['dm', 'kb', 'ku', 'thetar', 's0', 'gmax', 'thetax', 'Kt', 'M', 'we', 'Km', 'vm', 'nx', 'Kq', 'vt', 'wr', 'wq', 'nq', 'nr', 'ns', 'Kgamma', 'Cm', 'k_cm', 'kin', 'kdeath']
    return [param_dict[key] for key in order]

params = params_for_sim(params_dict)

init_dict = {
    'mt_0': 0.,
    'mm_0': 0.,
    'mq_0': 0.,
    'mr_0': 0.,
    'ct_0': 0.,
    'cm_0': 0.,
    'cq_0': 0.,
    'cr_0': 0.,
    'et_0': 1.,
    'em_0': 1.,
    'q_0': 0.,
    'r_0': 1.0,
    'si_0': 0.,
    'a_0':  0.0,
    'zmt_0':0, 
    'zmm_0':0, 
    'zmq_0':0, 
    'zmr_0':0,
    's_0' : 1e12,
    'N_0' : 1
}

def init_for_sim(init_dict):
    order = ['mt_0', 'mm_0', 'mq_0', 'mr_0', 'ct_0', 'cm_0', 'cq_0', 'cr_0', 'et_0', 'em_0', 'q_0', 'r_0', 'si_0', 'a_0', 'zmt_0', 'zmm_0', 'zmq_0', 'zmr_0', 's_0', 'N_0']
    return [init_dict[key] for key in order]

init = init_for_sim(init_dict)

# %%
params_dict1 = params_dict.copy()
params_dict1['dm'] = params_dict['dm']/10
params_dict1['kb'] = params_dict['kb']*10
params_dict1['ku'] = params_dict['ku']/10
params_dict1['thetar'] = params_dict['thetar']*10
params_dict1['thetax'] = params_dict['thetax']*10
params_dict1['Kt'] = params_dict['Kt']*10
params_dict1['Km'] = params_dict['Km']*10
params_dict1['vm'] = params_dict['vm']*10
params_dict1['vt'] = params_dict['vt']*10
params_dict1['Kq'] = params_dict['Kq']/10
params_dict1['Kgamma'] = params_dict['Kgamma']*10
params1 = params_for_sim(params_dict1)

params_dict2 = params_dict.copy()
params_dict2['Kgamma'] = 1e5
params_dict2['Kq'] = 1e4
params2 = params_for_sim(params_dict2)

params_dict3 = params_dict.copy()
params_dict3['Kgamma'] = params_dict['Kgamma'] /2 # half the original value
params_dict3['vt'] = params_dict['vt'] *2
params_dict3['vm'] = params_dict['vm'] *2
params3 = params_for_sim(params_dict3)

params_dict4 = params_dict.copy()
params_dict4['ku'] = params_dict['ku'] * 10 # half the original value
params_dict4['vt'] = params_dict['vt'] * 10
params_dict4['dm'] = params_dict['dm'] * 10
params4 = params_for_sim(params_dict4)

params_dict5 = params_dict.copy()
params_dict5['Kgamma'] = 1
params_dict5['Kq'] = 1
params_dict5['ku'] = 20
params5 = params_for_sim(params_dict5)

params_dict6 = params_dict.copy()
params_dict6['Kgamma'] = params_dict6['Kgamma']/100 
params_dict6['Kt'] = 1.0e8 
params_dict6['vt'] = 1000 
params_dict6['Km'] = 1.0e8 
params_dict6['vm'] = 1000
params6 = params_for_sim(params_dict6)

params_full = np.concatenate([params1, params2, params3, params4, params5, params6])

# %%
sol1 = solve_ivp(abx_model, (0, 1e9), init[:-2], args=(params1[:-2],), method='Radau')
sol2 = solve_ivp(abx_model, (0, 1e9), init[:-2], args=(params2[:-2],), method='Radau')
sol3 = solve_ivp(abx_model, (0, 1e9), init[:-2], args=(params3[:-2],), method='Radau')
sol4 = solve_ivp(abx_model, (0, 1e9), init[:-2], args=(params4[:-2],), method='Radau')
sol5 = solve_ivp(abx_model, (0, 1e9), init[:-2], args=(params5[:-2],), method='Radau')
sol6 = solve_ivp(abx_model, (0, 1e9), init[:-2], args=(params6[:-2],), method='Radau')

cell1 = np.concatenate([sol1.y[:, -1], [init_dict['s_0']], [init_dict['N_0']]])
cell2 = np.concatenate([sol2.y[:, -1], [init_dict['s_0']], [init_dict['N_0']]])
cell3 = np.concatenate([sol3.y[:, -1], [init_dict['s_0']], [init_dict['N_0']]])
cell4 = np.concatenate([sol4.y[:, -1], [init_dict['s_0']], [init_dict['N_0']]])
cell5 = np.concatenate([sol5.y[:, -1], [init_dict['s_0']], [init_dict['N_0']]])
cell6 = np.concatenate([sol6.y[:, -1], [init_dict['s_0']], [init_dict['N_0']]])

init_full = np.concatenate([cell1, cell2, cell3, cell4, cell5, cell6])

# %%
sol_comp = solve_ivp(competition_ode_big, (0, 1e4), init_full, args=(params_full,), method='Radau')

plt.plot(sol_comp.t, sol_comp.y[19], label='Population 1')
plt.plot(sol_comp.t, sol_comp.y[39], label='Population 2')
plt.plot(sol_comp.t, sol_comp.y[59], label='Population 3')
plt.plot(sol_comp.t, sol_comp.y[79], label='Population 4')
plt.plot(sol_comp.t, sol_comp.y[99], label='Population 5')
plt.plot(sol_comp.t, sol_comp.y[119], label='Population 6')
plt.xlabel('Time')
plt.ylabel('Population Size')
plt.legend()
# Out:
# /var/folders/f3/c1y27g054d15_b8tbt5p8fk40000gq/T/ipykernel_18373/938005941.py:18: RuntimeWarning: overflow encountered in scalar power
#   return (w * a / (theta + a)) / (1 + (q / (Kq )) ** nq)

# %%
tm = 2000

# %%
# run the model up to t=1000
sol_comp1 = solve_ivp(competition_ode_big, (0, tm), init_full, args=(params_full,), method='Radau')

# %%
# conditions
Cm = 1
ns = 0.7

# %%
# change parameters to include antibiotic for both populations
params_dict_new1 = params_dict1.copy()
params_dict_new1['Cm'] = Cm
params_dict_new1['ns'] = ns
params1_condition = params_for_sim(params_dict_new1)

params_dict_new2 = params_dict2.copy()
params_dict_new2['Cm'] = Cm
params_dict_new2['ns'] = ns
params2_condition = params_for_sim(params_dict_new2)

params_dict_new3 = params_dict3.copy()
params_dict_new3['Cm'] = Cm
params_dict_new3['ns'] = ns
params3_condition = params_for_sim(params_dict_new3)

params_dict_new4 = params_dict4.copy()
params_dict_new4['Cm'] = Cm
params_dict_new4['ns'] = ns
params4_condition = params_for_sim(params_dict_new4)

params_dict_new5 = params_dict5.copy()
params_dict_new5['Cm'] = Cm
params_dict_new5['ns'] = ns
params5_condition = params_for_sim(params_dict_new5)

params_dict_new6 = params_dict6.copy()
params_dict_new6['Cm'] = Cm
params_dict_new6['ns'] = ns
params6_condition = params_for_sim(params_dict_new6)

params_full_new = np.concatenate([params1_condition, params2_condition, params3_condition, params4_condition, params5_condition, params6_condition])

# %%
# use the last state as new initial conditions
init_pop_new = sol_comp1.y[:, -1]

# solve from 1000 onwards
sol_comp2 = solve_ivp(competition_ode_big, (tm, 4000), init_pop_new, args=(params_full_new,), method='Radau')

# %%
t_combined = np.concatenate([sol_comp1.t, sol_comp2.t])
y_combined = np.concatenate([sol_comp1.y, sol_comp2.y], axis=1)

plt.plot(t_combined, y_combined[19], label='Reactor invadors (1)')
plt.plot(t_combined, y_combined[39], label='Xmen (2)')
plt.plot(t_combined, y_combined[59], label='Suboptimal growth (3)')
plt.plot(t_combined, y_combined[79], label='Scan (4)')
# plt.plot(t_combined, y_combined[99], label='The Weisse guys (5)')
plt.plot(t_combined, y_combined[119], label='The mutant pancakes (6)')
plt.axvline(x=tm, color='red', linestyle='--', alpha=0.7, label='Parameter change')

plt.xlabel('Time')
plt.ylabel('Population Size')
plt.legend()
